# %%
import os

# %%
print(os.path)
# Out:
# <module 'ntpath' from 'C:\\Program Files\\Anaconda3\\lib\\ntpath.py'>

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
PATH = 'C:\\Users\\а\\PycharmProjects\\names'

# %%
tables = {x.split(os.sep)[-1].split('.')[0][3:]: get_table(x) for x in glob.glob(os.path.join(PATH, '*.txt'))}

# %%
def get_table(path):
    colums = ['Name', 'Gender', 'Count']
    table = pd.read_csv(path, names = colums)
    return table

# %%
def make_table(names, years, step = 1):
    table_data = {'Year' : [x for x in range(years[0], years[1] + 1, step)]}
    for name in names:
        table_data[name] = [name_sum(x, name) for x in range(years[0], years[1] + 1, step)]
    return pd.DataFrame(table_data)

# %%
def name_sum(year, name):
    table = tables[str(year)]
    #return table
    return table.query('Name == "{}"'.format(name)).groupby('Name').sum()['Count'].values[0]

# %%
make_table(['Ruth', 'Robert'], [1900, 2000]).plot(x = 'Year')

# %%
make_table(['Ruth', 'Robert'], [1900, 2000], 5).plot.bar(x = 'Year')

# %%
test = tables['1950']

# %%
def find_names(string, year):
    names = []
    for name in tables[str(year)]['Name'].values:
        if name[:len(string)] == string:
            names.append(name)
    return names

# %%
# не нашел как сделать фильтр или запрос, где Name == 'R*',
# поэтому сделал отдельную функцию find_names для получения списка таких имен
# кроме того, график для R* выглядит плохо, поэтому сделал для Roe*
tables['1950'].query('Name == {}'.format(find_names('Roe', 1950))).groupby('Name').sum().plot.pie(y='Count')

# %%
def make_full_table(years):
    new_tables = []
    for year in range(years[0], years[1] + 1):
        new_table = tables[str(year)].apply(name_to_len, axis=1).groupby('Name').sum().reset_index()
        new_tables.append(new_table)
    return pd.concat(new_tables)

# %%
def name_to_len(row):
    row.Name = len(row.Name)
    return row

# %%
#сделать такую таблицу на 100 лет будет слишком долго, поэтому я взял промежуток 1960-1980
make_full_table([1960,1980]).plot.scatter(x='Name', y='Count')
